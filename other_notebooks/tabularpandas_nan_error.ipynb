# %% [markdown]
# # `TabularPandas` and missing value errors
#
# When processing new data using an pre-existing instance of `TabularPandas` I've encountered the following error:
#
# AssertionError: nan values in `cont_prop` but not in setup training set
#
# `cont_prop` is a column with a missing value in this example below.
#
# The origin of this problem is that no missing values were seen for that column during the setup phase of the `TabularPandas` object where the transforms were applied.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from fastai2.tabular.all import *
from fastai2 import metrics

# %% [markdown]
# ## Test on a simple data frame

# %% [markdown]
# Let's generate `df` to create the initial `TabularPandas` object (`to`) for, which is usually then later used for the tabular learner. Let's also create a `df_test` which will be the unseen data on which we will want to use `to.new(df_test)`.

# %%
def get_simple_df(n):
    return pd.DataFrame({
        "cat_prop": np.random.choice(["a", "b", "c"], size=n),
        "cont_prop": np.random.uniform(size=n)
    })

n = 10
n_test = 5

df = get_simple_df(n)
df = df.append(pd.DataFrame({"cat_prop":["b", None], "cont_prop": [np.nan, .6]}),
               ignore_index=True)
df_test = get_simple_df(n_test)
df_test = df_test.append(pd.DataFrame({"cat_prop":["a", None], "cont_prop": [np.nan, .5]}),
                         ignore_index=True)

df, df_test
# Out:
# (   cat_prop  cont_prop
#  0         a   0.266686
#  1         c   0.151567
#  2         c   0.166479
#  3         a   0.034086
#  4         b   0.700573
#  5         c   0.862857
#  6         c   0.307003
#  7         a   0.770959
#  8         b   0.873119
#  9         a   0.286313
#  10        b        NaN
#  11     None   0.600000,
#    cat_prop  cont_prop
#  0        a   0.933491
#  1        c   0.331430
#  2        b   0.786464
#  3        a   0.895200
#  4        b   0.683861
#  5        a        NaN
#  6     None   0.500000)

# %%
cat_names = ["cat_prop"]
cont_names = ["cont_prop"]

# %% [markdown]
# The assertion error due to a missing value will be caused if the validation or test set have nans in columns where the train set did not have any. So let's exclude row 10 from the training set.

# %%
dep_var = "y"
df[dep_var] = np.linspace(-1,1,len(df))**2
val_col = "is_valid"
df[val_col] = True
df.loc[4:,val_col] = False
# causing an error by excluding the sole null value for that column 
# from the setup, if not patched with, e.g., an additional row
df.loc[10,val_col] = True  
df
# Out:
#    cat_prop  cont_prop         y  is_valid
# 0         a   0.266686  1.000000      True
# 1         c   0.151567  0.669421      True
# 2         c   0.166479  0.404959      True
# 3         a   0.034086  0.206612      True
# 4         b   0.700573  0.074380     False
# 5         c   0.862857  0.008264     False
# 6         c   0.307003  0.008264     False
# 7         a   0.770959  0.074380     False
# 8         b   0.873119  0.206612     False
# 9         a   0.286313  0.404959     False
# 10        b        NaN  0.669421      True
# 11     None   0.600000  1.000000     False

# %% [markdown]
# What `FillMissing.setups` will see

# %%
pd.isnull(df.loc[df[val_col]==False]).any()
# Out:
# cat_prop      True
# cont_prop    False
# y            False
# is_valid     False
# dtype: bool

# %% [markdown]
# So far so good. `cont_prop` does not appear to have nan values in the training set.
#
# To fix this problem, without having to modify any of the fastai2 code, let's add a single row setting the column(s), where we expect to find nans in the future, to nan.
#
# Skip this next two cells if you want to produce the assertion error for nan values

# %%
row = df.loc[df[val_col]==False,:].sample(n=1)
row["cont_prop"] = np.nan
row
# Out:
#   cat_prop  cont_prop         y  is_valid
# 8        c        NaN  0.206612     False

# %% [markdown]
# Now append this row to `df`

# %%
df = df.append(row, ignore_index=True)

# %%
df
# Out:
#    cat_prop  cont_prop         y  is_valid
# 0         a   0.266686  1.000000      True
# 1         c   0.151567  0.669421      True
# 2         c   0.166479  0.404959      True
# 3         a   0.034086  0.206612      True
# 4         b   0.700573  0.074380     False
# 5         c   0.862857  0.008264     False
# 6         c   0.307003  0.008264     False
# 7         a   0.770959  0.074380     False
# 8         b   0.873119  0.206612     False
# 9         a   0.286313  0.404959     False
# 10        b        NaN  0.669421      True
# 11     None   0.600000  1.000000     False

# %% [markdown]
# As you can see there is now a row 12 whose `cont_prop` value is nan and belongs to the training set (`is_valid == False`)

# %%
pd.isnull(df.loc[df[val_col]==False]).any()
# Out:
# cat_prop      True
# cont_prop    False
# y            False
# is_valid     False
# dtype: bool

# %% [markdown]
# The `FillMissing.setups` sanity check also shows that the column of the training set now contains nan

# %%
procs = [Categorify, FillMissing, Normalize]
splits = ColSplitter(col=val_col)(df)

# %%
df["cat_prop"] = pd.Categorical(df["cat_prop"])

# %%
to = TabularPandas(df, procs=procs, cat_names=cat_names, cont_names=cont_names,
                   y_names=dep_var, splits=splits)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-51-fd63e5caeb17> in <module>
#       1 to = TabularPandas(df, procs=procs, cat_names=cat_names, cont_names=cont_names,
# ----> 2                    y_names=dep_var, splits=splits)
#
# ~/git_clones/fastai2/fastai2/tabular/core.py in __init__(self, df, procs, cat_names, cont_names, y_names, block_y, splits, do_setup, device, inplace)
#     121         self.cat_names,self.cont_names,self.procs = L(cat_names),L(cont_names),Pipeline(procs)
#     122         self.split = len(df) if splits is None else len(splits[0])
# --> 123         if do_setup: self.setup()
#     124
#     125     def new(self, df):
#
# ~/git_clones/fastai2/fastai2/tabular/core.py in setup(self)
#     132     def decode_row(self, row): return self.new(pd.DataFrame(row).T).decode().items.iloc[0]
#     133     def show(self, max_n=10, **kwargs): display_df(self.new(self.all_cols[:max_n]).decode().items)
# --> 134     def setup(self): self.procs.setup(self)
#     135     def process(self): self.procs(self)
#     136     def loc(self): return self.items.loc
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in setup(self, items, train_setup)
#     177         tfms = self.fs[:]
#     178         self.fs.clear()
# --> 179         for t in tfms: self.add(t,items, train_setup)
#     180
#     181     def add(self,t, items=None, train_setup=False):
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in add(self, t, items, train_setup)
#     180
#     181     def add(self,t, items=None, train_setup=False):
# --> 182         t.setup(items, train_setup)
#     183         self.fs.append(t)
#     184
#
# ~/git_clones/fastai2/fastai2/tabular/core.py in setup(self, items, train_setup)
#     178         super().setup(getattr(items,'train',items), train_setup=False)
#     179         # Procs are called as soon as data is available
# --> 180         return self(items.items if isinstance(items,Datasets) else items)
#     181
#     182 # Cell
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in __call__(self, x, **kwargs)
#      70     @property
#      71     def name(self): return getattr(self, '_name', _get_name(self))
# ---> 72     def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#      73     def decode  (self, x, **kwargs): return self._call('decodes', x, **kwargs)
#      74     def __repr__(self): return f'{self.name}: {self.encodes} {self.decodes}'
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in _call(self, fn, x, split_idx, **kwargs)
#      94     "A `Transform` that modifies in-place and just returns whatever it's passed"
#      95     def _call(self, fn, x, split_idx=None, **kwargs):
# ---> 96         super()._call(fn,x,split_idx,**kwargs)
#      97         return x
#      98
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in _call(self, fn, x, split_idx, **kwargs)
#      81         if split_idx!=self.split_idx and self.split_idx is not None: return x
#      82         f = getattr(self, fn)
# ---> 83         if not _is_tuple(x): return self._do_call(f, x, **kwargs)
#      84         res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      85         return retain_type(res, x)
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/transform.py in _do_call(self, f, x, **kwargs)
#      86
#      87     def _do_call(self, f, x, **kwargs):
# ---> 88         return x if f is None else retain_type(f(x, **kwargs), x, f.returns_none(x))
#      89
#      90 add_docs(Transform, decode="Delegate to `decodes` to undo transform", setup="Delegate to `setups` to set up transform")
#
# ~/anaconda3/envs/py37_fastai2/lib/python3.7/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#      96         if not f: return args[0]
#      97         if self.inst is not None: f = MethodType(f, self.inst)
# ---> 98         return f(*args, **kwargs)
#      99
#     100     def __get__(self, inst, owner):
#
# ~/git_clones/fastai2/fastai2/tabular/core.py in encodes(self, to)
#     262         missing = pd.isnull(to.conts)
#     263         for n in missing.any()[missing.any()].keys():
# --> 264             assert n in self.na_dict, f"nan values in `{n}` but not in setup training set"
#     265         for n in self.na_dict.keys():
#     266             to[n].fillna(self.na_dict[n], inplace=True)
#
# AssertionError: nan values in `cont_prop` but not in setup training set

# %%
to.na_dict
# Out:
# {'cont_prop': 0.6269944329852075}

# %%
to_val = to.new(df)

# %%
to_val.process()

# %%
to_test = to.new(df_test)

# %%
to_test.process()

# %% [markdown]
# ## Test on house prices data frames

# %% [markdown]
# An actual data set where the above problem occurs is the house sale prices one can find on kaggle. So let's apply the above fix

# %%
df = pd.read_csv("../data/train.csv")
df_test = pd.read_csv("../data/test.csv")

# %%
procs = [Categorify, FillMissing, Normalize]
valid_pct = .2
val_col = "is_valid"
df[val_col] = np.random.choice([True, False], size=len(df), p=[1-valid_pct, valid_pct])

# %%
dep_var = "SalePrice"

# %%
cont_names = ['LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF2', 'BsmtUnfSF',
              'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea',
              'WoodDeckSF', 'OpenPorchSF', 'LotFrontage', 'BsmtFinSF1', 'LowQualFinSF',]

# %%
cat_names = ['Id', 'MSSubClass', 'MSZoning', 'Street',
             'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
             'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
             'HouseStyle', 'OverallQual', 'OverallCond', 
             'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
             'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
             'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
             'BsmtFinType2', 'Heating',
             'HeatingQC', 'CentralAir', 'Electrical', 
             'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
             'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
             'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
             'GarageFinish', 'GarageCars', 'GarageQual',
             'GarageCond', 'PavedDrive',
             'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
             'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'SaleType',
             'SaleCondition']

# %% [markdown]
# In case we only want to use a subset of the columns for testing

# %%
df = df.loc[:, cont_names+cat_names+[val_col, dep_var]]
df_test = df_test.loc[:, cont_names+cat_names]

# %%
def display_all(df):
    "Extended displaying of a data frame"
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000):
        display(df)

# %%
pd.isnull(df).any()[pd.isnull(df).any()]
# Out:
# MasVnrArea      True
# GarageYrBlt     True
# LotFrontage     True
# Alley           True
# MasVnrType      True
# BsmtQual        True
# BsmtCond        True
# BsmtExposure    True
# BsmtFinType1    True
# BsmtFinType2    True
# Electrical      True
# FireplaceQu     True
# GarageType      True
# GarageFinish    True
# GarageQual      True
# GarageCond      True
# PoolQC          True
# Fence           True
# MiscFeature     True
# dtype: bool

# %% [markdown]
# Continuous columns with nan values in the training, validation and test

# %%
na_cont_cols_train = [col for col in cont_names if df.loc[df[val_col]==False, col].hasnans]
na_cont_cols_train
# Out:
# ['MasVnrArea', 'GarageYrBlt', 'LotFrontage']

# %%
na_cont_cols_valid = [col for col in cont_names if df.loc[df[val_col]==True, col].hasnans]
na_cont_cols_valid
# Out:
# ['MasVnrArea', 'GarageYrBlt', 'LotFrontage']

# %%
na_cont_cols_test = [col for col in cont_names if df_test[col].hasnans]
na_cont_cols_test
# Out:
# ['MasVnrArea',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'GarageYrBlt',
#  'GarageArea',
#  'LotFrontage',
#  'BsmtFinSF1']

# %% [markdown]
# Merging the three lists above

# %%
na_cont_cols = list(set(na_cont_cols_train + na_cont_cols_valid + na_cont_cols_test))
na_cont_cols
# Out:
# ['LotFrontage',
#  'GarageArea',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFinSF2',
#  'GarageYrBlt',
#  'BsmtFinSF1',
#  'MasVnrArea']

# %% [markdown]
# Select a random row to do the fix

# %%
row = df.loc[df["is_valid"]==False,:].sample(n=1).copy(); display_all(row.T)
# Out:
#                    953
# LotArea          11075
# YearBuilt         1969
# YearRemodAdd      1969
# MasVnrArea         232
# BsmtFinSF2         193
# BsmtUnfSF           29
# TotalBsmtSF        784
# 1stFlrSF          1168
# 2ndFlrSF           800
# GrLivArea         1968
# GarageYrBlt       1969
# GarageArea         530
# WoodDeckSF         305
# OpenPorchSF        189
# LotFrontage        NaN
# BsmtFinSF1         562
# LowQualFinSF         0
# Id                 954
# MSSubClass          60
# MSZoning            RL
# Street            Pave
# Alley              NaN
# LotShape           IR1
# LandContour        Lvl
# Utilities       AllPub
# LotConfig       Inside
# LandSlope          Mod
# Neighborhood   Mitchel
# Condition1        Norm
# Condition2        Norm
# BldgType          1Fam
# HouseStyle      2Story
# OverallQual          5
# OverallCond          4
# RoofStyle        Gable
# RoofMatl       CompShg
# Exterior1st    HdBoard
# Exterior2nd    HdBoard
# MasVnrType     BrkFace
# ExterQual           TA
# ExterCond           TA
# Foundation      CBlock
# BsmtQual            TA
# BsmtCond            TA
# BsmtExposure        Av
# BsmtFinType1       ALQ
# BsmtFinType2       LwQ
# Heating           GasA
# HeatingQC           Ex
# CentralAir           Y
# Electrical       SBrkr
# BsmtFullBath         0
# BsmtHalfBath         1
# FullBath             2
# HalfBath             1
# BedroomAbvGr         4
# KitchenAbvGr         1
# KitchenQual         TA
# TotRmsAbvGrd         7
# Functional        Min2
# Fireplaces           1
# FireplaceQu         Po
# GarageType      Attchd
# GarageFinish       RFn
# GarageCars           2
# GarageQual          TA
# GarageCond          TA
# PavedDrive           Y
# EnclosedPorch        0
# 3SsnPorch            0
# ScreenPorch          0
# PoolArea             0
# PoolQC             NaN
# Fence            MnPrv
# MiscFeature       Shed
# MiscVal            400
# MoSold               9
# SaleType            WD
# SaleCondition   Normal
# is_valid         False
# SalePrice       172000

# %% [markdown]
# Setting the column values to nan

# %%
row[na_cont_cols] = np.nan
display_all(row.T)
# Out:
#                    953
# LotArea          11075
# YearBuilt         1969
# YearRemodAdd      1969
# MasVnrArea         NaN
# BsmtFinSF2         NaN
# BsmtUnfSF          NaN
# TotalBsmtSF        NaN
# 1stFlrSF          1168
# 2ndFlrSF           800
# GrLivArea         1968
# GarageYrBlt        NaN
# GarageArea         NaN
# WoodDeckSF         305
# OpenPorchSF        189
# LotFrontage        NaN
# BsmtFinSF1         NaN
# LowQualFinSF         0
# Id                 954
# MSSubClass          60
# MSZoning            RL
# Street            Pave
# Alley              NaN
# LotShape           IR1
# LandContour        Lvl
# Utilities       AllPub
# LotConfig       Inside
# LandSlope          Mod
# Neighborhood   Mitchel
# Condition1        Norm
# Condition2        Norm
# BldgType          1Fam
# HouseStyle      2Story
# OverallQual          5
# OverallCond          4
# RoofStyle        Gable
# RoofMatl       CompShg
# Exterior1st    HdBoard
# Exterior2nd    HdBoard
# MasVnrType     BrkFace
# ExterQual           TA
# ExterCond           TA
# Foundation      CBlock
# BsmtQual            TA
# BsmtCond            TA
# BsmtExposure        Av
# BsmtFinType1       ALQ
# BsmtFinType2       LwQ
# Heating           GasA
# HeatingQC           Ex
# CentralAir           Y
# Electrical       SBrkr
# BsmtFullBath         0
# BsmtHalfBath         1
# FullBath             2
# HalfBath             1
# BedroomAbvGr         4
# KitchenAbvGr         1
# KitchenQual         TA
# TotRmsAbvGrd         7
# Functional        Min2
# Fireplaces           1
# FireplaceQu         Po
# GarageType      Attchd
# GarageFinish       RFn
# GarageCars           2
# GarageQual          TA
# GarageCond          TA
# PavedDrive           Y
# EnclosedPorch        0
# 3SsnPorch            0
# ScreenPorch          0
# PoolArea             0
# PoolQC             NaN
# Fence            MnPrv
# MiscFeature       Shed
# MiscVal            400
# MoSold               9
# SaleType            WD
# SaleCondition   Normal
# is_valid         False
# SalePrice       172000

# %% [markdown]
# `df`'s nan status before appending the row

# %%
pd.isnull(df.loc[df[val_col]==False, na_cont_cols]).any()
# Out:
# LotFrontage     True
# GarageArea     False
# BsmtUnfSF      False
# TotalBsmtSF    False
# BsmtFinSF2     False
# GarageYrBlt     True
# BsmtFinSF1     False
# MasVnrArea      True
# dtype: bool

# %% [markdown]
# Creating the patched dataframe `df_p`

# %%
print(len(df))
df_p = df.append(row, ignore_index=True)
print(len(df_p))
# Out:
# 1460
# 1461

# %% [markdown]
# `df`'s nan status after appending the row

# %%
pd.isnull(df_p.loc[df_p[val_col]==False, na_cont_cols]).any()
# Out:
# LotFrontage    True
# GarageArea     True
# BsmtUnfSF      True
# TotalBsmtSF    True
# BsmtFinSF2     True
# GarageYrBlt    True
# BsmtFinSF1     True
# MasVnrArea     True
# dtype: bool

# %% [markdown]
# Generating `to`

# %%
dep_var = "SalePrice"
splits = ColSplitter(col=val_col)(df_p)
to = TabularPandas(df_p, procs=procs, cat_names=list(cat_names), 
                   cont_names=list(cont_names),
                   y_names=dep_var, splits=splits)

# %%
to.na_dict
# Out:
# {'MasVnrArea': 0.0,
#  'BsmtFinSF2': 0.0,
#  'BsmtUnfSF': 401.5,
#  'TotalBsmtSF': 1011.0,
#  'GarageYrBlt': 1979.0,
#  'GarageArea': 476.0,
#  'LotFrontage': 70.0,
#  'BsmtFinSF1': 439.5}

# %%
to_val = to.new(df)

# %%
to_val.process()

# %%
to_test = to.new(df_test)

# %%
to_test.process()
